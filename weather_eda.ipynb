# %%
# Reading my weather dataset which is in the csv fromat got this from visualcrossing.com
import pandas as pd
import numpy as np

#Parsing Dates within my weather dataset and converting it to a standard
def myDateConv(tt):
    sep = tt[2]
    if sep == '-':
        return pd.to_datetime(tt, format='%m-%d-%y')
    elif sep == '/':
        return pd.to_datetime(tt, format='%m/%d/%Y')
    else:
        return tt
    
weather_data = pd.read_csv("C:/Users/Rehanawajahat/Desktop/Data Analytics and Programming/Project/history_data.csv",converters={'Date time': myDateConv})
print(weather_data)
# Out:
#                Name  Wind Direction  Latitude  Cloud Cover  \
# 0      South Dublin          201.92   53.3411         46.9
# 1      South Dublin          212.92   53.3411         54.6
# 2      South Dublin          269.00   53.3411         42.0
# 3      South Dublin          228.79   53.3411         56.7
# 4      South Dublin          211.54   53.3411         57.7
# ...             ...             ...       ...          ...
# 12439       Wicklow          244.71   52.9807         63.0
# 12440       Wicklow          297.21   52.9807         84.1
# 12441       Wicklow          294.21   52.9807         63.4
# 12442       Wicklow          256.63   52.9807         61.5
# 12443       Wicklow          289.13   52.9807         71.0
#
#        Minimum Temperature  Date time  Precipitation  Solar Radiation  \
# 0                      0.5 2020-01-01           0.00              NaN
# 1                      7.3 2020-01-02           0.66              NaN
# ...

# %%
# Reading my weather dataset which is in the csv fromat got this from visualcrossing.com
import pandas as pd
import numpy as np

#Parsing Dates within my weather dataset and converting it to a standard
def myDateConv(tt):
    sep = tt[2]
    if sep == '-':
        return pd.to_datetime(tt, format='%m-%d-%y')
    elif sep == '/':
        return pd.to_datetime(tt, format='%m/%d/%Y')
    else:
        return tt
# Assign the filename: file
file = "C://Users/Rehanawajahat/Desktop/Data Analytics and Programming/Project/history_data.csv"
# Read the file into a DataFrame: df
weather_df = pd.read_csv(file,converters={'Date time': myDateConv})
print(weather_df)
# Out:
#                Name  Wind Direction  Latitude  Cloud Cover  \
# 0      South Dublin          201.92   53.3411         46.9
# 1      South Dublin          212.92   53.3411         54.6
# 2      South Dublin          269.00   53.3411         42.0
# 3      South Dublin          228.79   53.3411         56.7
# 4      South Dublin          211.54   53.3411         57.7
# ...             ...             ...       ...          ...
# 12439       Wicklow          244.71   52.9807         63.0
# 12440       Wicklow          297.21   52.9807         84.1
# 12441       Wicklow          294.21   52.9807         63.4
# 12442       Wicklow          256.63   52.9807         61.5
# 12443       Wicklow          289.13   52.9807         71.0
#
#        Minimum Temperature  Date time  Precipitation  Solar Radiation  \
# 0                      0.5 2020-01-01           0.00              NaN
# 1                      7.3 2020-01-02           0.66              NaN
# ...

# %%
#Analyzing the dataframe
print(weather_data.head())
# Out:
#            Name  Wind Direction  Latitude  Cloud Cover  Minimum Temperature  \
# 0  South Dublin          201.92   53.3411         46.9                  0.5
# 1  South Dublin          212.92   53.3411         54.6                  7.3
# 2  South Dublin          269.00   53.3411         42.0                  3.1
# 3  South Dublin          228.79   53.3411         56.7                  5.2
# 4  South Dublin          211.54   53.3411         57.7                  7.1
#
#    Date time  Precipitation  Solar Radiation  Dew Point  Relative Humidity  \
# 0 2020-01-01           0.00              NaN        2.4              84.65
# 1 2020-01-02           0.66              NaN        7.1              84.58
# 2 2020-01-03           0.64              NaN        3.0              85.41
# 3 2020-01-04           0.20              NaN        5.0              89.01
# 4 2020-01-05           0.30              NaN        6.6              85.93
#
#    ... Solar Energy  Heat Index  \
# ...

# %%
#Question 1: Find all the unique wind speed values recorded in the dataset
#Analyzing the dataframe using head(),index(),.nunique(),.unique() methods
# View the head of the DataFrame
print(weather_df.head(2))

weather_df.describe()

weather_df.info()

#.nunique() this method, which belongs to the series object can be useful when trying to identify the unique values in a column
weather_df["Wind Speed"].nunique()
weather_df["Wind Speed"].unique()
# Out:
#            Name  Wind Direction  Latitude  Cloud Cover  Minimum Temperature  \
# 0  South Dublin          201.92   53.3411         46.9                  0.5
# 1  South Dublin          212.92   53.3411         54.6                  7.3
#
#    Date time  Precipitation  Solar Radiation  Dew Point  Relative Humidity  \
# 0 2020-01-01           0.00              NaN        2.4              84.65
# 1 2020-01-02           0.66              NaN        7.1              84.58
#
#    ... Solar Energy  Heat Index  \
# 0  ...          NaN         NaN
# 1  ...          NaN         NaN
#
#                                         Weather Type Snow Depth  \
# 0                 Mist, Fog, Sky Coverage Decreasing        0.0
# 1  Drizzle, Light Drizzle, Rain, Light Drizzle/Ra...        0.0
#
#    Sea Level Pressure  Snow        Name.1  Wind Gust              Conditions  \
# 0              1025.5   0.0  South Dublin        NaN        Partially cloudy
# ...

# %%
#Question 2: Rename the column names of the dataframe
#Renaming the column names to friendlier names or renaming column names in the weather DataFrame
weather_df.rename({'Name':'name','Wind Direction':'wind_direction','Latitude':'latitude','Cloud Cover':'cloud_cover','Minimum Temperature':'min_temp','Date time':'date_time','Precipitation':'precipitation','Solar Radiation':'solar_radiation','Dew Point':'dew_point','Relative Humidity':'relative_humidity','ID':'id','Precipitation Cover':'precip_cover','Longitude':'longitude','Temperature':'temperature','Maximum Temperature':'max_temp','Visibility':'visibility','Wind Speed':'wind_speed','Solar Energy':'solar_energy','Heat Index':'heat_index','Weather Type':'weather_type','Snow Depth':'snow_depth','Sea Level Pressure':'sealevel_pressure','Snow':'snow','Wind Gust':'wind_gust','Conditions':'conditions','Wind Chill':'wind_chill'},axis=1, inplace=True)
weather_df.head(5)
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 0  South Dublin          201.92   53.3411         46.9       0.5 2020-01-01
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
# 2  South Dublin          269.00   53.3411         42.0       3.1 2020-01-03
# 3  South Dublin          228.79   53.3411         56.7       5.2 2020-01-04
# 4  South Dublin          211.54   53.3411         57.7       7.1 2020-01-05
#
#    precipitation  solar_radiation  dew_point  relative_humidity  ...  \
# 0           0.00              NaN        2.4              84.65  ...
# 1           0.66              NaN        7.1              84.58  ...
# 2           0.64              NaN        3.0              85.41  ...
# 3           0.20              NaN        5.0              89.01  ...
# 4           0.30              NaN        6.6              85.93  ...
#
#   solar_energy  heat_index                                       weather_type  \
# ...

# %%
#Question 3: Find the number of times when the weather was exactly weather condition is 'Clear'?
#Show data
weather_df.head(2)
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 0  South Dublin          201.92   53.3411         46.9       0.5 2020-01-01
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
#
#    precipitation  solar_radiation  dew_point  relative_humidity  ...  \
# 0           0.00              NaN        2.4              84.65  ...
# 1           0.66              NaN        7.1              84.58  ...
#
#   solar_energy  heat_index                                       weather_type  \
# 0          NaN         NaN                 Mist, Fog, Sky Coverage Decreasing
# 1          NaN         NaN  Drizzle, Light Drizzle, Rain, Light Drizzle/Ra...
#
#   snow_depth  sealevel_pressure  snow        Name.1  wind_gust  \
# 0        0.0             1025.5   0.0  South Dublin        NaN
# 1        0.0             1009.4   0.0  South Dublin       76.0
#
#                conditions  wind_chill
# 0        Partially cloudy        -3.4
# ...

# %%
#Step 1: Create a DataFFrame using Pandas
df1= pd.DataFrame(weather_df, columns=["wind_direction","cloud_cover","precipitation","dew_point","relative_humidity","sealevel_pressure"])
print(df1.head())
# Out:
#    wind_direction  cloud_cover  precipitation  dew_point  relative_humidity  \
# 0          201.92         46.9           0.00        2.4              84.65
# 1          212.92         54.6           0.66        7.1              84.58
# 2          269.00         42.0           0.64        3.0              85.41
# 3          228.79         56.7           0.20        5.0              89.01
# 4          211.54         57.7           0.30        6.6              85.93
#
#    sealevel_pressure
# 0             1025.5
# 1             1009.4
# 2             1024.3
# 3             1032.3
# 4             1026.1

# %%
df1
# Out:
#        wind_direction  cloud_cover  precipitation  dew_point  \
# 0              201.92         46.9           0.00        2.4
# 1              212.92         54.6           0.66        7.1
# 2              269.00         42.0           0.64        3.0
# 3              228.79         56.7           0.20        5.0
# 4              211.54         57.7           0.30        6.6
# ...               ...          ...            ...        ...
# 12439          244.71         63.0          13.19        0.8
# 12440          297.21         84.1           4.07        1.8
# 12441          294.21         63.4           0.20        0.9
# 12442          256.63         61.5           0.00       -0.9
# 12443          289.13         71.0           1.77       -0.1
#
#        relative_humidity  sealevel_pressure
# 0                  84.65             1025.5
# 1                  84.58             1009.4
# 2                  85.41             1024.3
# 3                  89.01             1032.3
# ...

# %%
#Step 2: Create a Correlation Matrix using Pandas
corrMatrix = df1.corr()

# %%
#Step 3: Printing correlation matrix
corrMatrix
# Out:
#                    wind_direction  cloud_cover  precipitation  dew_point  \
# wind_direction           1.000000     0.084748       0.048497  -0.154766
# cloud_cover              0.084748     1.000000       0.162103   0.113688
# precipitation            0.048497     0.162103       1.000000   0.157003
# dew_point               -0.154766     0.113688       0.157003   1.000000
# relative_humidity        0.040785     0.444801       0.264387   0.230791
# sealevel_pressure       -0.195296    -0.201794      -0.353524  -0.038284
#
#                    relative_humidity  sealevel_pressure
# wind_direction              0.040785          -0.195296
# cloud_cover                 0.444801          -0.201794
# precipitation               0.264387          -0.353524
# dew_point                   0.230791          -0.038284
# relative_humidity           1.000000          -0.289283
# sealevel_pressure          -0.289283           1.000000

# %%
#Step 4: Get a visual representation of the Correlation Matrix using Seaborn and Matplotlib
import seaborn as sn
import matplotlib.pyplot as plt

sn.heatmap(corrMatrix, annot=True)
plt.show()

# %%
#value_counts
weather_df["conditions"].value_counts()
# Out:
# Rain, Partially cloudy    6412
# Rain, Overcast            2116
# Partially cloudy          1984
# Clear                     1041
# Rain                       483
# Overcast                   259
# Snow, Partially cloudy      72
# Snow, Overcast              69
# Snow                         8
# Name: conditions, dtype: int64

# %%
# Using filtering 
weather_df[weather_df["conditions"]=="Clear"]
# Out:
#               name  wind_direction  latitude  cloud_cover  min_temp  \
# date_time
# 2020-01-01  Antrim          177.58   54.7156         78.8       4.3
# 2020-01-02  Antrim          202.71   54.7156         63.1       6.1
# 2020-01-03  Antrim          257.67   54.7156         57.9       4.0
# 2020-01-04  Antrim          210.83   54.7156         78.1       5.7
# 2020-01-05  Antrim          197.54   54.7156         92.2       7.6
# ...            ...             ...       ...          ...       ...
# 2020-12-27  Antrim          229.17   54.7156         63.3       1.1
# 2020-12-28  Antrim          311.38   54.7156         71.5       1.2
# 2020-12-29  Antrim          327.33   54.7156         41.3       0.7
# 2020-12-30  Antrim          252.13   54.7156         48.8      -0.8
# 2020-12-31  Antrim          312.46   54.7156         60.4      -0.5
#
#             precipitation  dew_point  relative_humidity      id  precip_cover  \
# date_time
# ...

# %%
type(weather_df["conditions"])
# Out:
# pandas.core.series.Series

# %%
#groupby()
weather_df.groupby("conditions").get_group("Clear")
# Out:
#                name  wind_direction  latitude  cloud_cover  min_temp  \
# 126    South Dublin           98.00   53.3411         22.9       5.0
# 134    South Dublin          214.21   53.3411         24.6      -2.0
# 463          Antrim          169.21   54.7156         18.2       4.4
# 469          Antrim           74.13   54.7156         12.6       2.1
# 470          Antrim          178.71   54.7156          4.2      -1.0
# ...             ...             ...       ...          ...       ...
# 12070       Wexford          337.13   52.3374          4.6       1.1
# 12188       Wicklow           78.38   52.9807         24.5       3.8
# 12212       Wicklow          215.25   52.9807         25.0      -2.1
# 12230       Wicklow           98.58   52.9807         24.5       8.4
# 12347       Wicklow          238.50   52.9807         19.9       1.1
#
#        date_time  precipitation  solar_radiation  dew_point  \
# 126   2020-05-06            0.0            397.0        4.2
# ...

# %%
#Question 4: Find the number of times when the windspeed was exactly 25.2km/h?

#weather_df["wind_speed"].describe()
#weather_df["wind_speed"].value_counts()
weather_df[weather_df["wind_speed"]==25.2]
# Out:
#                name  wind_direction  latitude  cloud_cover  min_temp  \
# 24     South Dublin          202.29   53.3411         59.4       4.9
# 447          Antrim          138.25   54.7156         47.6       3.6
# 649          Antrim          297.67   54.7156         66.2       8.6
# 710          Antrim          147.79   54.7156         81.6       7.1
# 1349         Carlow          233.29   52.8370         78.8      15.8
# ...             ...             ...       ...          ...       ...
# 12216       Wicklow          223.21   52.9807         60.7      10.9
# 12269       Wicklow          293.92   52.9807         47.9       7.4
# 12329       Wicklow          237.21   52.9807         72.4      16.0
# 12341       Wicklow           84.42   52.9807         62.0       7.2
# 12421       Wicklow          180.63   52.9807         80.9       2.1
#
#        date_time  precipitation  solar_radiation  dew_point  \
# 24    2020-01-25           0.20             85.3        4.1
# ...

# %%
#Question 5: Find out all the Null values in the data?
#isnull()
weather_df.isnull().sum()
# Out:
# name                     0
# wind_direction           0
# latitude                 0
# cloud_cover              0
# min_temp                 0
# date_time                0
# precipitation            0
# solar_radiation       9585
# dew_point                0
# relative_humidity        0
# id                       0
# precip_cover             0
# longitude                0
# Info                 12442
# temperature              0
# max_temp                 0
# visibility               0
# wind_speed               0
# solar_energy          9585
# heat_index           11968
# weather_type          1326
# snow_depth               0
# sealevel_pressure        0
# snow                     0
# Name.1                   0
# wind_gust             6104
# conditions               0
# wind_chill            3718
# dtype: int64

# %%
# Question 6: Drop all the columns with the null values
#Drop the Columns such as info, solar_radiation, solar_energy, heat_index etc with over 6k missing values drop them as well.
weather_df.drop(['Info','solar_radiation', 'solar_energy', 'heat_index'],axis = 'columns',inplace=True)

weather_df.head()
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 0  South Dublin          201.92   53.3411         46.9       0.5 2020-01-01
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
# 2  South Dublin          269.00   53.3411         42.0       3.1 2020-01-03
# 3  South Dublin          228.79   53.3411         56.7       5.2 2020-01-04
# 4  South Dublin          211.54   53.3411         57.7       7.1 2020-01-05
#
#    precipitation  dew_point  relative_humidity            id  ...  visibility  \
# 0           0.00        2.4              84.65  South Dublin  ...        15.4
# 1           0.66        7.1              84.58  South Dublin  ...        15.9
# 2           0.64        3.0              85.41  South Dublin  ...        18.9
# 3           0.20        5.0              89.01  South Dublin  ...        16.6
# 4           0.30        6.6              85.93  South Dublin  ...        19.0
#
# ...

# %%
#Question 7: What is the mean value of the 'visibility' in km?
weather_df["visibility"].mean()
# Out:
# 26.661218257794864

# %%
#Question 8: What is the Standard deviation of the 'pressure' in this dataframe?
weather_df["sealevel_pressure"].std()
# Out:
# 12.362843666748466

# %%
#Question 9: What is the Variance of the 'Relative Humidity' in this historic weather data?
weather_df["relative_humidity"].var()
# Out:
# 97.15703613174978

# %% [markdown]
# #Question 10: Find all instances when snow was recorded?
# https://www.youtube.com/watch?v=13VVODn3GeE

# %%
#value_counts()
weather_df["conditions"].value_counts()
# Out:
# Rain, Partially cloudy    6412
# Rain, Overcast            2116
# Partially cloudy          1984
# Clear                     1041
# Rain                       483
# Overcast                   259
# Snow, Partially cloudy      72
# Snow, Overcast              69
# Snow                         8
# Name: conditions, dtype: int64

# %%
#use filtering
weather_df[weather_df["conditions"]=="Snow"]
# Out:
#             name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 5864   Fermanagh          187.21   40.5861          9.4      -9.9 2020-01-09
# 5875   Fermanagh          328.67   40.5861         23.2      -7.4 2020-01-20
# 5877   Fermanagh          242.17   40.5861          1.2      -9.2 2020-01-22
# 5968   Fermanagh          294.46   40.5861         15.9       0.4 2020-04-22
# 6518      Fingal          303.00   46.7604          7.0      -9.3 2020-10-23
# 6535      Fingal          281.63   46.7604         24.8      -7.5 2020-11-09
# 11317     Tyrone          223.00   40.6779         24.4      -1.9 2020-12-03
# 11399  Waterford          205.42   42.6931          4.3      -1.6 2020-02-23
#
#        precipitation  dew_point  relative_humidity         id  ...  \
# 5864             0.0      -12.0              57.69  Fermanagh  ...
# 5875             0.0      -14.0              50.23  Fermanagh  ...
# 5877             0.0      -10.1              65.36  Fermanagh  ...
# ...

# %%
#use filtering
#weather_df["weather_type"].value_counts()
#weather_df[weather_df["weather_type"]=="Drizzle"]
weather_df[weather_df["weather_type"]=="Fog"]
# Out:
#                          name  wind_direction  latitude  cloud_cover  \
# 128              South Dublin          160.83   53.3411         43.8
# 220              South Dublin          135.79   53.3411         25.3
# 263              South Dublin           83.08   53.3411         60.1
# 477                    Antrim           73.08   54.7156          0.1
# 516                    Antrim           98.67   54.7156          7.6
# 518                    Antrim          102.33   54.7156          1.7
# 587                    Antrim           90.25   54.7156         68.8
# 843                    Armagh           82.92   54.3489          5.4
# 1116                   Carlow          226.83   52.8370         31.9
# 2301                     Cork           92.50   51.8983         20.9
# 3514                    Meath          119.96   53.6304         22.9
# 4543                  Donegal          105.46   54.6543          4.4
# 4886                   Dublin          163.67   53.3481         44.0
# ...

# %%
#str.contains()
weather_df[weather_df["conditions"].str.contains("Snow")]
# Out:
#             name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 5856   Fermanagh          292.38   40.5861         57.0      -3.4 2020-01-01
# 5862   Fermanagh          203.04   40.5861         43.1      -2.7 2020-01-07
# 5863   Fermanagh          296.58   40.5861         57.4      -5.4 2020-01-08
# 5864   Fermanagh          187.21   40.5861          9.4      -9.9 2020-01-09
# 5873   Fermanagh          135.21   40.5861         74.2      -5.8 2020-01-18
# ...          ...             ...       ...          ...       ...        ...
# 11705  Waterford          282.29   42.6931         98.1      -7.8 2020-12-25
# 11706  Waterford          247.13   42.6931        100.0      -6.6 2020-12-26
# 11708  Waterford          270.83   42.6931         78.8      -3.8 2020-12-28
# 11709  Waterford          218.38   42.6931         80.6      -6.7 2020-12-29
# 11710  Waterford          204.75   42.6931        100.0      -3.3 2020-12-30
#
# ...

# %%
#str.contains()
weather_df[weather_df["conditions"].str.contains("Overcast")]
# Out:
#                name  wind_direction  latitude  cloud_cover  min_temp  \
# 23     South Dublin          236.63   53.3411         84.1       5.1
# 180    South Dublin          252.38   53.3411         83.5      10.9
# 189    South Dublin           73.54   53.3411         76.4      10.9
# 228    South Dublin           62.58   53.3411         91.1      14.5
# 229    South Dublin           70.79   53.3411         77.0      14.8
# ...             ...             ...       ...          ...       ...
# 12433       Wicklow          180.75   52.9807         90.2       2.3
# 12435       Wicklow          129.58   52.9807         80.6       2.8
# 12437       Wicklow          241.63   52.9807         86.5      -1.6
# 12438       Wicklow          237.08   52.9807         93.2       6.0
# 12440       Wicklow          297.21   52.9807         84.1       2.8
#
#        date_time  precipitation  dew_point  relative_humidity            id  \
# ...

# %% [markdown]
# Question 11: Find all instances when wind speed was above 24 and visibility was 25?

# %%
weather_df[(weather_df["wind_speed"] > 24) & (weather_df["visibility"]==25)]
# Out:
#                name  wind_direction  latitude  cloud_cover  min_temp  \
# 256    South Dublin          223.79   53.3411         33.3      14.7
# 268    South Dublin          298.29   53.3411         29.2       3.8
# 813          Armagh          167.58   54.3489         40.9       2.2
# 1031         Armagh          284.38   54.3489         35.1       6.1
# 1243         Carlow          215.67   52.8370         46.6       6.1
# 1770          Cavan          241.29   53.9892         74.2       3.6
# 3285        Leitrim          248.63   54.1398         48.6       2.3
# 3415          Meath          272.13   53.6304         44.5       4.1
# 8500    Londonderry          173.92   54.9929         71.2       4.1
# 8813       Longford          209.79   53.7293         71.9       5.6
# 9103       Longford          225.96   53.7293         63.4       6.5
# 9687       Monaghan          175.83   54.2476         46.5       8.4
# 10022     Roscommon          174.29   53.6305         24.9       9.9
# ...

# %% [markdown]
# Question 12: What is the mean value of each colun against weach weather condition?

# %%
weather_df.groupby("conditions").mean()
# Out:
#                         wind_direction   latitude  cloud_cover  min_temp  \
# conditions
# Clear                       176.924841  36.753556    11.338713  6.394236
# Overcast                    202.747259  50.210757    85.634363  4.263707
# Partially cloudy            177.116714  50.338775    48.754889  5.927571
# Rain                        198.068778  36.724273    15.552588  6.290683
# Rain, Overcast              202.743355  52.576692    84.075662  8.237996
# Rain, Partially cloudy      215.921096  51.445686    55.721959  6.944947
# Snow                        258.195000  42.404525    13.775000 -5.800000
# Snow, Overcast              216.830000  42.399203    88.123188 -3.924638
# Snow, Partially cloudy      225.534306  42.880147    56.244444 -5.975000
#
#                         precipitation  dew_point  relative_humidity  \
# conditions
# Clear                        0.000000   6.029395          69.596993
# Overcast                     0.000000   3.703861          81.055676
# ...

# %% [markdown]
# Question 13: What is the minimum and maximum value of each column against each weather condition?

# %%
weather_df.groupby("weather_type").min()
# Out:
#                                                          name  wind_direction  \
# weather_type
# Blowing Or Drifting Snow, Heavy Snow, Light Sno...     Fingal          153.33
# Blowing Or Drifting Snow, Light Snow                Waterford          297.92
# Blowing Or Drifting Snow, Light Snow, Mist, Lig...     Fingal          278.33
# Blowing Or Drifting Snow, Light Snow, Mist, Smo...  Waterford          282.29
# Blowing Or Drifting Snow, Light Snow, Mist, Snow    Waterford          282.54
# ...                                                       ...             ...
# Thunderstorm, Fog                                      Fingal          116.13
# Thunderstorm, Light Rain                            Fermanagh          196.33
# Thunderstorm, Rain Showers, Sky Coverage Increa...      Kerry          142.33
# Thunderstorm, Rain, Heavy Rain, Light Rain, Sky...      Kerry          146.04
# Thunderstorm, Sky Coverage Increasing                   Kerry          172.21
#
# ...

# %%
weather_df.groupby("weather_type").max().head()
# Out:
#                                                          name  wind_direction  \
# weather_type
# Blowing Or Drifting Snow, Heavy Snow, Light Sno...  Waterford          338.79
# Blowing Or Drifting Snow, Light Snow                Waterford          297.92
# Blowing Or Drifting Snow, Light Snow, Mist, Lig...     Fingal          278.33
# Blowing Or Drifting Snow, Light Snow, Mist, Smo...  Waterford          282.29
# Blowing Or Drifting Snow, Light Snow, Mist, Snow    Waterford          282.54
#
#                                                     latitude  cloud_cover  \
# weather_type
# Blowing Or Drifting Snow, Heavy Snow, Light Sno...   46.7604         85.5
# Blowing Or Drifting Snow, Light Snow                 42.6931         83.5
# Blowing Or Drifting Snow, Light Snow, Mist, Lig...   46.7604         56.6
# Blowing Or Drifting Snow, Light Snow, Mist, Smo...   42.6931         98.1
# Blowing Or Drifting Snow, Light Snow, Mist, Snow     42.6931         57.4
#
# ...

# %% [markdown]
# Question 14: Show all the records where weather condition is fog?

# %%
weather_df[weather_df["weather_type"]=="Fog"]
# Out:
#                          name  wind_direction  latitude  cloud_cover  \
# 128              South Dublin          160.83   53.3411         43.8
# 220              South Dublin          135.79   53.3411         25.3
# 263              South Dublin           83.08   53.3411         60.1
# 477                    Antrim           73.08   54.7156          0.1
# 516                    Antrim           98.67   54.7156          7.6
# 518                    Antrim          102.33   54.7156          1.7
# 587                    Antrim           90.25   54.7156         68.8
# 843                    Armagh           82.92   54.3489          5.4
# 1116                   Carlow          226.83   52.8370         31.9
# 2301                     Cork           92.50   51.8983         20.9
# 3514                    Meath          119.96   53.6304         22.9
# 4543                  Donegal          105.46   54.6543          4.4
# 4886                   Dublin          163.67   53.3481         44.0
# ...

# %% [markdown]
# Question 15: Find all insances when weather is clear or visibility is above 40?

# %%
weather_df["conditions"].value_counts()
# Out:
# Rain, Partially cloudy    6412
# Rain, Overcast            2116
# Partially cloudy          1984
# Clear                     1041
# Rain                       483
# Overcast                   259
# Snow, Partially cloudy      72
# Snow, Overcast              69
# Snow                         8
# Name: conditions, dtype: int64

# %%
weather_df[(weather_df["conditions"]=="Clear") | (weather_df["visibility"] >40)]
# Out:
#                name  wind_direction  latitude  cloud_cover  min_temp  \
# 126    South Dublin           98.00   53.3411         22.9       5.0
# 134    South Dublin          214.21   53.3411         24.6      -2.0
# 392          Antrim          191.83   54.7156         62.1       1.5
# 393          Antrim          232.04   54.7156         64.3       0.1
# 453          Antrim           39.00   54.7156         62.8       4.1
# ...             ...             ...       ...          ...       ...
# 12071       Wexford          273.33   52.3374         60.4       0.7
# 12188       Wicklow           78.38   52.9807         24.5       3.8
# 12212       Wicklow          215.25   52.9807         25.0      -2.1
# 12230       Wicklow           98.58   52.9807         24.5       8.4
# 12347       Wicklow          238.50   52.9807         19.9       1.1
#
#        date_time  precipitation  dew_point  relative_humidity            id  \
# ...

# %% [markdown]
# Manipulating pandas DataFrames
# Exploratory data analysis
# Data wrangling
# Data preprocessing
# Building models
# visualization

# %%
# Build a numpy array from the DataFrame: data_array
weather_df_array = weather_df.values
print(weather_df.head())
weather_df.tail()
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 0  South Dublin          201.92   53.3411         46.9       0.5 2020-01-01
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
# 2  South Dublin          269.00   53.3411         42.0       3.1 2020-01-03
# 3  South Dublin          228.79   53.3411         56.7       5.2 2020-01-04
# 4  South Dublin          211.54   53.3411         57.7       7.1 2020-01-05
#
#    precipitation  dew_point  relative_humidity            id  ...  visibility  \
# 0           0.00        2.4              84.65  South Dublin  ...        15.4
# 1           0.66        7.1              84.58  South Dublin  ...        15.9
# 2           0.64        3.0              85.41  South Dublin  ...        18.9
# 3           0.20        5.0              89.01  South Dublin  ...        16.6
# 4           0.30        6.6              85.93  South Dublin  ...        19.0
#
# ...

# %%
# Print the datatype of weather_df_array to the shell
print(type(weather_df_array))
# Out:
# <class 'numpy.ndarray'>

# %%
#Customizing your pandas import
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot 'Precipitation' variable in a histogram

pd.DataFrame.hist(weather_df[['precipitation']])
plt.xlabel('precipitation (millimetres)')
plt.ylabel('count')
plt.show()

# %%
#Customizing your pandas import

# Plot all variables in df using a histogram

pd.DataFrame.hist(weather_df)
#plt.xlabel('precipitation (millimetres)')
plt.ylabel('count')
plt.show()

# %%
#Handling Missing values
# Detect missing values in weather_df
# Print the 'info' of 'weather_df'
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12444 entries, 0 to 12443
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               12444 non-null  object
#  1   wind_direction     12444 non-null  float64
#  2   latitude           12444 non-null  float64
#  3   cloud_cover        12444 non-null  float64
#  4   min_temp           12444 non-null  float64
#  5   date_time          12444 non-null  datetime64[ns]
#  6   precipitation      12444 non-null  float64
#  7   dew_point          12444 non-null  float64
#  8   relative_humidity  12444 non-null  float64
#  9   id                 12444 non-null  object
#  10  precip_cover       12444 non-null  float64
#  11  longitude          12444 non-null  float64
#  12  temperature        12444 non-null  float64
#  13  max_temp           12444 non-null  float64
#  14  visibility         12444 non-null  float64
# ...

# %%
# Detect missing values in the weather dataset

#Let's apply unique method on Precipitation column
precipitation_unique = weather_df.precipitation.unique()
np.sort(precipitation_unique)

# From the output I observe 
precipitation_unique
# Out:
# array([ 0.  ,  0.66,  0.64, ..., 18.34, 17.13, 13.19])

# %%
weather_df.temperature.describe() # Precipitation cannot be 0.0000 these are missing values
# Out:
# count    12444.000000
# mean        10.077572
# std          5.665235
# min        -26.700000
# 25%          6.500000
# 50%          9.700000
# 75%         13.700000
# max         28.800000
# Name: temperature, dtype: float64

# %%
weather_df[weather_df.precipitation == 0] = np.nan
# Store all rows of column 'Precipitation' which are equal to 0.000000

zero_precip = weather_df.precipitation[np.isnan(weather_df.precipitation)] 
# Print variable zero_precip
zero_precip

# Successfully removed the hidden missing values 0.000 under Precipitation columns and replaced them with 'NaN'
#Summarise: 1. Detect missing value character like empty values, '.' etc
#           2. Detect the inherent missing values within the data like '0'.
#           3. Replace them values with NaN
# Out:
# 0       NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 21      NaN
#          ..
# 12420   NaN
# 12427   NaN
# 12436   NaN
# 12437   NaN
# 12442   NaN
# Name: precipitation, Length: 3341, dtype: float64

# %% [markdown]
# #Steps involved in the Exploratory Data analysis
# # Understand the data
# # Clean the data
# # Analysis of Relationship between the variables

# %% [markdown]
# #Cleaning and preparing data

# %%
#Analyze the amount of missingness

#Nullity of the DataFrame
#use either .isnull() or isna() methods on the DataFrame

weather_nullity = weather_df.isnull()
weather_nullity.head(10)
# Out:
#     name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 0   True            True      True         True      True       True
# 1  False           False     False        False     False      False
# 2  False           False     False        False     False      False
# 3  False           False     False        False     False      False
# 4  False           False     False        False     False      False
# 5  False           False     False        False     False      False
# 6  False           False     False        False     False      False
# 7  False           False     False        False     False      False
# 8  False           False     False        False     False      False
# 9  False           False     False        False     False      False
#
#    precipitation  dew_point  relative_humidity     id  ...  visibility  \
# 0           True       True               True   True  ...        True
# ...

# %%
#obtaining total missing values in the dataframe
# Calculate total of missing values
weather_nullity.sum()
# Out:
# name                 3341
# wind_direction       3341
# latitude             3341
# cloud_cover          3341
# min_temp             3341
# date_time            3341
# precipitation        3341
# dew_point            3341
# relative_humidity    3341
# id                   3341
# precip_cover         3341
# longitude            3341
# temperature          3341
# max_temp             3341
# visibility           3341
# wind_speed           3341
# weather_type         3565
# snow_depth           3341
# sealevel_pressure    3341
# snow                 3341
# Name.1               3341
# wind_gust            7319
# conditions           3341
# wind_chill           6070
# dtype: int64

# %%
#Caulculating percentage of missingness
weather_nullity.mean() * 100
# Out:
# name                 26.848280
# wind_direction       26.848280
# latitude             26.848280
# cloud_cover          26.848280
# min_temp             26.848280
# date_time            26.848280
# precipitation        26.848280
# dew_point            26.848280
# relative_humidity    26.848280
# id                   26.848280
# precip_cover         26.848280
# longitude            26.848280
# temperature          26.848280
# max_temp             26.848280
# visibility           26.848280
# wind_speed           26.848280
# weather_type         28.648345
# snow_depth           26.848280
# sealevel_pressure    26.848280
# snow                 26.848280
# Name.1               26.848280
# wind_gust            58.815493
# conditions           26.848280
# wind_chill           48.778528
# dtype: float64

# %% [markdown]
# #Handling missing data
# #replacing na values in weather_df with mean precipitation value
# weather_df["precipitation"].fillna("3.505193",inplace = True)
# weather_df["dew_point"].fillna("6.782723",inplace = True)
# weather_df["relative_humidity"].fillna("81.476937",inplace = True)
# weather_df["temperature"].fillna("9.933692",inplace = True)
# weather_df["wind_speed"].fillna("25.675378",inplace = True)
# #weather_df.precipitation.head(5)
# #weather_df.precipitation.tail(5)
# weather_df.head()

# %%
# We can tell pandas to drop all rows that have a missing value in all the columns. Because we specify a subset, the .dropna() method
#Examine the shape of the DataFrame
print(weather_df.shape)
# Out:
# (12444, 24)

# %%
weather_df.isnull().sum()
# Out:
# name                 3341
# wind_direction       3341
# latitude             3341
# cloud_cover          3341
# min_temp             3341
# date_time            3341
# precipitation        3341
# dew_point            3341
# relative_humidity    3341
# id                   3341
# precip_cover         3341
# longitude            3341
# temperature          3341
# max_temp             3341
# visibility           3341
# wind_speed           3341
# weather_type         3565
# snow_depth           3341
# sealevel_pressure    3341
# snow                 3341
# Name.1               3341
# wind_gust            7319
# conditions           3341
# wind_chill           6070
# dtype: int64

# %%
#Examine the shape of the dataFrame (again)
print(weather_df.shape)
# Out:
# (12444, 24)

# %%
#.dropna() method is a great way to drop rows based on the presence of missing values in that row.
#Drop the missing values (3341) in each, because calculating mean/median values for that large data will skew your analysis. 
#Best thing to do is remove all those rows. We will still have about 9.1k rows of data to work with for your analysis.
weather_df.dropna(subset=['precipitation'],inplace=True)

# %%
print(weather_df.shape)
# Out:
# (9103, 24)

# %% [markdown]
# Below we will be analyzing the amount of missingness numerically
# the amount of missingness graphically
# the percentage of missingness
# the nullity matrix for regular datasets

# %%
#Let us now graphically visualize the amount of missingness using Missingno package
#Missingno package is used for graphical anallysis of missing values

# import missingno package
import missingno as msno

#Plot amount of missingness
msno.bar(weather_df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(weather_df)
# Out:
# <AxesSubplot:>

# %%
msno.matrix(weather_df,freq='M')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-0ecc3d6df714> in <module>
# ----> 1 msno.matrix(weather_df,freq='M')
#
# ~\Anaconda3\lib\site-packages\missingno\missingno.py in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#     110                                                     t.strftime('%Y-%m-%d'))
#     111         else:
# --> 112             raise KeyError('Dataframe index must be PeriodIndex or DatetimeIndex.')
#     113         try:
#     114             for value in ts_array:
#
# KeyError: 'Dataframe index must be PeriodIndex or DatetimeIndex.'

# %% [markdown]
# #Missingness pattern of the weather_df sorted by

# %% [markdown]
# # Plot the sliced nullity matrix of weather_df with frequency 'M'
# #msno.matrix(weather_df.loc['01-01-20':'01-02-20'],freq='M')

# %%
weather_df.precipitation.isnull()
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 12438    False
# 12439    False
# 12440    False
# 12441    False
# 12443    False
# Name: precipitation, Length: 9103, dtype: bool

# %%
weather_df.plot.hist(bins=15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Handling missing values
weather_df.isnull().sum()
# Out:
# name                    0
# wind_direction          0
# latitude                0
# cloud_cover             0
# min_temp                0
# date_time               0
# precipitation           0
# dew_point               0
# relative_humidity       0
# id                      0
# precip_cover            0
# longitude               0
# temperature             0
# max_temp                0
# visibility              0
# wind_speed              0
# weather_type          224
# snow_depth              0
# sealevel_pressure       0
# snow                    0
# Name.1                  0
# wind_gust            3978
# conditions              0
# wind_chill           2729
# dtype: int64

# %%
print(weather_df.wind_gust.describe(),weather_df.wind_chill.describe())
# Out:
# count    5125.000000
# mean       60.950654
# std        16.154286
# min        10.800000
# 25%        48.200000
# 50%        60.800000
# 75%        71.300000
# max       179.600000
# Name: wind_gust, dtype: float64 count    6374.000000
# mean        1.424035
# std         4.185781
# min       -40.100000
# 25%        -1.200000
# 50%         1.800000
# 75%         4.300000
# max         9.600000
# Name: wind_chill, dtype: float64

# %% [markdown]
# #Dealing with List Values in Pandas Dataframes
# https://towardsdatascience.com/dealing-with-list-values-in-pandas-dataframes-a177e534f173

# %%
#using va;lue_count() function to count how many times which county weather readings were observed.
weather_df["name"].value_counts()
# Out:
# Leitrim                   325
# Sligo                     323
# Londonderry               322
# Antrim                    321
# Cavan                     318
# Longford                  318
# Galway                    316
# Roscommon                 310
# Armagh                    310
# Westmeath                 310
# Monaghan                  310
# Donegal                   307
# Tipperary                 302
# Carlow                    292
# Laois                     290
# Offaly                    290
# Kildare                   289
# Meath                     289
# Kilkenny                  287
# Limerick                  284
# Dublin                    275
# South Dublin              275
# Dublin, Ireland           275
# Wicklow                   240
# Dún Laoghaire–Rathdown    240
# Wexford                   237
# Louth                     237
# Cork                      234
# Tyrone                    218
# Kerry                     192
# Clare                     180
# ...

# %%
#What if we want which weather type were named the most? In principle we have all the data we need for this in the weather_type column. 
#However, if we apply the same function, the recults are not helpful.
weather_df['weather_type'].value_counts()
# Out:
# Drizzle, Mist, Light Drizzle, Rain, Light Drizzle/Rain, Rain Showers, Light Rain, Sky Coverage Decreasing, Sky Coverage Increasing                                       124
# Drizzle, Rain, Rain Showers, Light Rain, Sky Coverage Decreasing, Sky Coverage Increasing                                                                                123
# Drizzle, Mist, Light Drizzle, Rain, Light Drizzle/Rain, Rain Showers, Light Rain, Sky Coverage Decreasing, Sky Coverage Increasing, Sky Unchanged                        115
# Drizzle, Light Drizzle, Rain, Light Drizzle/Rain, Rain Showers, Light Rain, Sky Coverage Decreasing, Sky Coverage Increasing                                             113
# Drizzle, Rain, Rain Showers, Light Rain, Sky Coverage Decreasing, Sky Coverage Increasing, Sky Unchanged                                                                 106
# ...

# %%
type(weather_df["weather_type"])
weather_df["weather_type"].dtype
# Out:
# dtype('O')

# %%
#Exporting or writing pandas weather_df to weather_df1.csv
weather_df.to_csv('weather_df1.csv',header = True, index = False,na_rep = '-')

# %%
#Reading the exported dataframe!
import pandas as pd

def myDateConv(tt):
    sep = tt[2]
    if sep == '-':
        return pd.to_datetime(tt, format='%m-%d-%y')
    elif sep == '/':
        return pd.to_datetime(tt, format='%m/%d/%Y')
    else:
        return tt
# Assign the filename: file
file1 = "C://Users/Rehanawajahat/Desktop/Data Analytics and Programming/Project/weather_df1.csv"
# Read the file into a DataFrame: df
data = pd.read_csv(file1,converters={'Date time': myDateConv})
print(data)
# View the head of the DataFrame
print(data.head())
# Out:
#               name  wind_direction  latitude  cloud_cover  min_temp  \
# 0     South Dublin          212.92   53.3411         54.6       7.3
# 1     South Dublin          269.00   53.3411         42.0       3.1
# 2     South Dublin          228.79   53.3411         56.7       5.2
# 3     South Dublin          211.54   53.3411         57.7       7.1
# 4     South Dublin          217.67   53.3411         46.7       5.7
# ...            ...             ...       ...          ...       ...
# 9098       Wicklow          237.08   52.9807         93.2       6.0
# 9099       Wicklow          244.71   52.9807         63.0       0.8
# 9100       Wicklow          297.21   52.9807         84.1       2.8
# 9101       Wicklow          294.21   52.9807         63.4       0.8
# 9102       Wicklow          289.13   52.9807         71.0      -1.5
#
#        date_time  precipitation  dew_point  relative_humidity            id  \
# ...

# %% [markdown]
# weather_df["weather_type"] = weather_df["weather_type"].astype("|S")

# %% [markdown]
# weather_df["weather_type"].dtype

# %%
data["weather_type"] = '['+data["weather_type"]+']'
def clean_alt_list(list_):
    list_ = list_.replace('[', '["')
    list_ = list_.replace(', ', '","')
    list_ = list_.replace(']', '"]')
    return list_
data["weather_type"] = data["weather_type"].astype(str).apply(clean_alt_list)

# %%
data["weather_type"].head()
# Out:
# 0    ["Drizzle","Light Drizzle","Rain","Light Drizz...
# 1    ["Rain","Light Drizzle/Rain","Sky Coverage Dec...
# 2    ["Drizzle","Mist","Light Drizzle","Rain","Rain...
# 3    ["Drizzle","Mist","Light Drizzle","Rain","Ligh...
# 4    ["Rain","Rain Showers","Light Rain","Sky Cover...
# Name: weather_type, dtype: object

# %%
data.dtypes

# %%
data["weather_type"].tolist()

# %%
pd.Series(data["weather_type"])
#weather_df["weather_type"].dtype

# %%
data["weather_type"] = data["weather_type"].apply(eval)

# %%
data["weather_type"][1]
# Out:
# ['Rain',
#  'Light Drizzle/Rain',
#  'Sky Coverage Decreasing',
#  'Sky Coverage Increasing']

# %%
# We need this piece of code for splitting string values with comma as delimiter
data = data.join(data["weather_type"].str.split(',', expand=True).add_prefix('weather_type'))

# %%
print(data.head())
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp   date_time  \
# 0  South Dublin          212.92   53.3411         54.6       7.3  2020-01-02
# 1  South Dublin          269.00   53.3411         42.0       3.1  2020-01-03
# 2  South Dublin          228.79   53.3411         56.7       5.2  2020-01-04
# 3  South Dublin          211.54   53.3411         57.7       7.1  2020-01-05
# 4  South Dublin          217.67   53.3411         46.7       5.7  2020-01-06
#
#    precipitation  dew_point  relative_humidity            id  ...  wind_speed  \
# 0           0.66        7.1              84.58  South Dublin  ...        36.2
# 1           0.64        3.0              85.41  South Dublin  ...        31.7
# 2           0.20        5.0              89.01  South Dublin  ...        21.6
# 3           0.30        6.6              85.93  South Dublin  ...        26.5
# 4           3.25        5.0              80.06  South Dublin  ...        44.1
#
# ...

# %%
data["name"].unique()
# Out:
# array(['South Dublin', 'Antrim', 'Armagh', 'Carlow', 'Cavan', 'Clare',
#        'Cork', 'Laois', 'Leitrim', 'Meath', 'Offaly', 'Westmeath',
#        'Donegal', 'Dublin', 'Dublin, Ireland', 'Dún Laoghaire–Rathdown',
#        'Fermanagh', 'Fingal', 'Galway', 'Kerry', 'Kildare', 'Kilkenny',
#        'Limerick', 'Londonderry', 'Longford', 'Louth', 'Monaghan',
#        'Roscommon', 'Sligo', 'Tipperary', 'Tyrone', 'Waterford',
#        'Wexford', 'Wicklow'], dtype=object)

# %%
weather_dict = {}
for i in data["weather_type"]:
    for j in data["weather_type"]:
        if j not in weather_dict:
            weather_dict[j] = 1
        else:
            weather_dict[j] += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-abc9bd14515d> in <module>
#       2 for i in data["weather_type"]:
#       3     for j in data["weather_type"]:
# ----> 4         if j not in weather_dict:
#       5             weather_dict[j] = 1
#       6         else:
#
# TypeError: unhashable type: 'list'

# %%
def to_1D(series):
 return pd.Series([x for _list in series for x in _list])

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (14,4))
ax.bar(to_1D(data["weather_type"]).value_counts().index,
        to_1D(data["weather_type"]).value_counts().values)
ax.set_ylabel("Frequency", size = 12)
ax.set_title("Type of weather", size = 14)

# %% [markdown]
# #Pandas use a list of values to select rows from a column
# https://www.youtube.com/watch?v=jlSbo5wmTPQ

# %%
# Reading activities_file dataset 
import pandas as pd
import numpy as np

activities_data = pd.read_csv(r"C:\Users\Rehanawajahat\Desktop\Data Analytics and Programming\Project\Datasets\Activities_latest.csv")

# %%
print(activities_data.head())
# Out:
#                                        Name  \
# 0         The Restaurant at the Abbey Hotel
# 1                             Café Nutshell
# 2              Guided Walking Tour of Sligo
# 3  Get West Limerick City Kayak & SUP Tours
# 4                       The Italian Kitchen
#
#                                            Url        Telephone  Longitude  \
# 0  http://www.abbeyhotel.ie/food-and-wine.html         3.54E+11  -8.193639
# 1       https://www.facebook.com/cafenutshell/      35351422777  -6.944210
# 2                                          NaN              NaN  -8.477043
# 3                        http://www.getwest.ie  +353(0)61278747  -8.630284
# 4                  http://theitaliankitchen.ie  +353(0)18711255  -6.218041
#
#     Latitude AddressRegion AddressLocality       AddressCountry  \
# 0  53.624876     Roscommon             NaN              Ireland
# 1  52.395136       Wexford        New Ross  Republic of Ireland
# ...

# %%
# Reading the csv into a dataFrame
activitiesfile = "C:/Users/Rehanawajahat/Desktop/Data Analytics and Programming/Project/Datasets/Activities_latest.csv"
activities_df = pd.read_csv(activitiesfile)
print(activities_df)

# View the head of the DataFrame
print(activities_df.head())
# Out:
#                                           Name  \
# 0            The Restaurant at the Abbey Hotel
# 1                                Café Nutshell
# 2                 Guided Walking Tour of Sligo
# 3     Get West Limerick City Kayak & SUP Tours
# 4                          The Italian Kitchen
# ...                                        ...
# 5408                            Chester Beatty
# 5409                             Theatre Royal
# 5410                      The Everyman Theatre
# 5411                       Triskel Arts Centre
# 5412                                   The Ark
#
#                                                   Url         Telephone  \
# 0         http://www.abbeyhotel.ie/food-and-wine.html          3.54E+11
# 1              https://www.facebook.com/cafenutshell/       35351422777
# 2                                                 NaN               NaN
# 3                               http://www.getwest.ie   +353(0)61278747
# ...

# %% [markdown]
# Data Wrangling

# %%
# There are a total of 5413 rows and 9 columns in the dataframe.

# Before handling missing data, create copy of activities_df
activities_df_missing = activities_df.copy()
df = activities_df_missing
#activities_df.head()

# For the merge-join of weather data for the project, the critical data is the Address region. 
# We will need to replace NaN in the AddressRegion column with correct region data.

# Identify missing values in the AddressRegion column
print (df[df['AddressRegion'].isna()])

# Select all rows with NaN under AddressRegion DataFrame column
nan_values = df[df['AddressRegion'].isna()]
print (nan_values)

# Confirm all empty fields using iloc function beginning with the First

df.iloc[379][5]

# Replace NaN values with a Region label based on the locality and URL

df.iat[379,5] = 'Cork'
df.iat[2186,5] = 'Cork'
df.iat[2191,5] = 'Donegal'
df.iat[2298,5] = 'Cork'
df.iat[2358,5] = 'Offaly'
df.iat[2908,5] = 'Wicklow'
df.iat[3167,5] = 'Mayo'
df.iat[3682,5] = 'Cork'
df.iat[3959,5] = 'Galway'
df.iat[3993,5] = 'Cork'

# Confirm No NaN are present in the AddressRegion Column

nan_values = df[df['AddressRegion'].isna()]
print (nan_values)

# The remaning NaN are acceptable as is some cases there are no fields present for these.
# Out:
#                                             Name  \
# 379                                 The Elm Tree
# 2186                            Cork Whale Watch
# 2191                      Knoxs Pub & Restaurant
# 2298                            Fishy Fishy Café
# 2358                       Mid Ireland Adventure
# 2908                           The Roundwood Inn
# 3167  Westport Skate Park & Multi-use Games Area
# 3682               Blairscove House & Restaurant
# 3959                             Killary Harbour
# 3993                       Toddies at the Bulman
#
#                                                     Url    Telephone  \
# 379                               http://www.elmtree.ie     3.53E+11
# 2186                      http://www.corkwhalewatch.com     3.54E+11
# 2191                                  https://knoxs.ie/     3.54E+11
# 2298                           http://www.fishyfishy.ie     3.53E+11
# 2358        http://www.facebook.com/MidIrelandAdventure     3.54E+11
# ...

# %%
activities_df=df

# %%
activities_df.head()
# Out:
#                                        Name  \
# 0         The Restaurant at the Abbey Hotel
# 1                             Café Nutshell
# 2              Guided Walking Tour of Sligo
# 3  Get West Limerick City Kayak & SUP Tours
# 4                       The Italian Kitchen
#
#                                            Url        Telephone  Longitude  \
# 0  http://www.abbeyhotel.ie/food-and-wine.html         3.54E+11  -8.193639
# 1       https://www.facebook.com/cafenutshell/      35351422777  -6.944210
# 2                                          NaN              NaN  -8.477043
# 3                        http://www.getwest.ie  +353(0)61278747  -8.630284
# 4                  http://theitaliankitchen.ie  +353(0)18711255  -6.218041
#
#     Latitude AddressRegion AddressLocality       AddressCountry  \
# 0  53.624876     Roscommon             NaN              Ireland
# 1  52.395136       Wexford        New Ross  Republic of Ireland
# ...

# %%
weather_df.head()
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
# 2  South Dublin          269.00   53.3411         42.0       3.1 2020-01-03
# 3  South Dublin          228.79   53.3411         56.7       5.2 2020-01-04
# 4  South Dublin          211.54   53.3411         57.7       7.1 2020-01-05
# 5  South Dublin          217.67   53.3411         46.7       5.7 2020-01-06
#
#    precipitation  dew_point  relative_humidity            id  ...  visibility  \
# 1           0.66        7.1              84.58  South Dublin  ...        15.9
# 2           0.64        3.0              85.41  South Dublin  ...        18.9
# 3           0.20        5.0              89.01  South Dublin  ...        16.6
# 4           0.30        6.6              85.93  South Dublin  ...        19.0
# 5           3.25        5.0              80.06  South Dublin  ...        17.0
#
# ...

# %%
weather_df.rename(columns = {'Name.1':'AddressRegion'}, inplace=True)

# %%
weather_df.head()
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
# 2  South Dublin          269.00   53.3411         42.0       3.1 2020-01-03
# 3  South Dublin          228.79   53.3411         56.7       5.2 2020-01-04
# 4  South Dublin          211.54   53.3411         57.7       7.1 2020-01-05
# 5  South Dublin          217.67   53.3411         46.7       5.7 2020-01-06
#
#    precipitation  dew_point  relative_humidity            id  ...  visibility  \
# 1           0.66        7.1              84.58  South Dublin  ...        15.9
# 2           0.64        3.0              85.41  South Dublin  ...        18.9
# 3           0.20        5.0              89.01  South Dublin  ...        16.6
# 4           0.30        6.6              85.93  South Dublin  ...        19.0
# 5           3.25        5.0              80.06  South Dublin  ...        17.0
#
# ...

# %%
weather_df.head()
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
# 2  South Dublin          269.00   53.3411         42.0       3.1 2020-01-03
# 3  South Dublin          228.79   53.3411         56.7       5.2 2020-01-04
# 4  South Dublin          211.54   53.3411         57.7       7.1 2020-01-05
# 5  South Dublin          217.67   53.3411         46.7       5.7 2020-01-06
#
#    precipitation  dew_point  relative_humidity            id  ...  visibility  \
# 1           0.66        7.1              84.58  South Dublin  ...        15.9
# 2           0.64        3.0              85.41  South Dublin  ...        18.9
# 3           0.20        5.0              89.01  South Dublin  ...        16.6
# 4           0.30        6.6              85.93  South Dublin  ...        19.0
# 5           3.25        5.0              80.06  South Dublin  ...        17.0
#
# ...

# %%
mergedOne = pd.merge(activities_df, weather_df, on='AddressRegion', how='inner')

# %%
mergedOne.head()
# Out:
#                                 Name  \
# 0  The Restaurant at the Abbey Hotel
# 1  The Restaurant at the Abbey Hotel
# 2  The Restaurant at the Abbey Hotel
# 3  The Restaurant at the Abbey Hotel
# 4  The Restaurant at the Abbey Hotel
#
#                                            Url Telephone  Longitude  \
# 0  http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 1  http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 2  http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 3  http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 4  http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
#
#     Latitude AddressRegion AddressLocality AddressCountry  \
# 0  53.624876     Roscommon             NaN        Ireland
# 1  53.624876     Roscommon             NaN        Ireland
# 2  53.624876     Roscommon             NaN        Ireland
# 3  53.624876     Roscommon             NaN        Ireland
# ...

# %%
mergedOne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1356443 entries, 0 to 1356442
# Data columns (total 32 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Name               1356443 non-null  object
#  1   Url                1265149 non-null  object
#  2   Telephone          1257611 non-null  object
#  3   Longitude          1356443 non-null  float64
#  4   Latitude           1356443 non-null  float64
#  5   AddressRegion      1356443 non-null  object
#  6   AddressLocality    1044301 non-null  object
#  7   AddressCountry     1356443 non-null  object
#  8   Tags               1337169 non-null  object
#  9   name               1356443 non-null  object
#  10  wind_direction     1356443 non-null  float64
#  11  latitude           1356443 non-null  float64
#  12  cloud_cover        1356443 non-null  float64
#  13  min_temp           1356443 non-null  float64
#  14  date_time          1356443 non-null  datetime64[ns]
# ...

# %%
weather_df['year'] = pd.DatetimeIndex(weather_df["date_time"]).year
weather_df['month'] = pd.DatetimeIndex(weather_df["date_time"]).month

# %%
weather_df['Month'] = pd.DatetimeIndex(weather_df["date_time"]).month

# %%
weather_df.head()
# Out:
#            name  wind_direction  latitude  cloud_cover  min_temp  date_time  \
# 1  South Dublin          212.92   53.3411         54.6       7.3 2020-01-02
# 2  South Dublin          269.00   53.3411         42.0       3.1 2020-01-03
# 3  South Dublin          228.79   53.3411         56.7       5.2 2020-01-04
# 4  South Dublin          211.54   53.3411         57.7       7.1 2020-01-05
# 5  South Dublin          217.67   53.3411         46.7       5.7 2020-01-06
#
#    precipitation  dew_point  relative_humidity            id  ...  snow_depth  \
# 1           0.66        7.1              84.58  South Dublin  ...         0.0
# 2           0.64        3.0              85.41  South Dublin  ...         0.0
# 3           0.20        5.0              89.01  South Dublin  ...         0.0
# 4           0.30        6.6              85.93  South Dublin  ...         0.0
# 5           3.25        5.0              80.06  South Dublin  ...         0.0
#
# ...

# %%
#weather_df['year'].head()
weather_df['month']
# Out:
# 1         1
# 2         1
# 3         1
# 4         1
# 5         1
#          ..
# 12438    12
# 12439    12
# 12440    12
# 12441    12
# 12443    12
# Name: month, Length: 9103, dtype: int64

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9103 entries, 1 to 12443
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9103 non-null   object
#  1   wind_direction     9103 non-null   float64
#  2   latitude           9103 non-null   float64
#  3   cloud_cover        9103 non-null   float64
#  4   min_temp           9103 non-null   float64
#  5   date_time          9103 non-null   datetime64[ns]
#  6   precipitation      9103 non-null   float64
#  7   dew_point          9103 non-null   float64
#  8   relative_humidity  9103 non-null   float64
#  9   id                 9103 non-null   object
#  10  precip_cover       9103 non-null   float64
#  11  longitude          9103 non-null   float64
#  12  temperature        9103 non-null   float64
#  13  max_temp           9103 non-null   float64
#  14  visibility         9103 non-null   float64
# ...

# %%
weather_df.set_index('date_time',inplace=True)

# %%
#weather_df.head()
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9103 entries, 2020-01-02 to 2020-12-31
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               9103 non-null   object
#  1   wind_direction     9103 non-null   float64
#  2   latitude           9103 non-null   float64
#  3   cloud_cover        9103 non-null   float64
#  4   min_temp           9103 non-null   float64
#  5   precipitation      9103 non-null   float64
#  6   dew_point          9103 non-null   float64
#  7   relative_humidity  9103 non-null   float64
#  8   id                 9103 non-null   object
#  9   precip_cover       9103 non-null   float64
#  10  longitude          9103 non-null   float64
#  11  temperature        9103 non-null   float64
#  12  max_temp           9103 non-null   float64
#  13  visibility         9103 non-null   float64
#  14  wind_speed         9103 non-null   float64
# ...

# %%
#for grouping converted month from int to list
weather_df.month.tolist()
#Obtain the mean value of each month grouping by month:
monthly_avg=weather_df.groupby('month').temperature.mean()
monthly_avg.head(12)
# Out:
# month
# 1      6.351675
# 2      5.786883
# 3      6.539394
# 4      9.012863
# 5     11.983368
# 6     13.744877
# 7     14.896690
# 8     15.649516
# 9     13.304301
# 10     9.776290
# 11     8.512806
# 12     5.353100
# Name: temperature, dtype: float64

# %%
# temperature, pressure, cloud cover, Humidity, wind speed, precip_cover

agg=weather_df.groupby(['AddressRegion','month']).mean()
agg
# Out:
#                      wind_direction  latitude  cloud_cover   min_temp  \
# AddressRegion month
# Antrim        1          204.412500   54.7156    60.810714   3.542857
#               2          217.939630   54.7156    62.233333   2.622222
#               3          216.225769   54.7156    56.553846   2.619231
#               4          174.027647   54.7156    59.452941   5.588235
#               5          202.729600   54.7156    59.592000   7.348000
# ...                             ...       ...          ...        ...
# Wicklow       8          186.220455   52.9807    62.486364  12.368182
#               9          234.253750   52.9807    53.775000   9.237500
#               10         211.003704   52.9807    67.148148   6.781481
#               11         209.696087   52.9807    74.565217   6.330435
#               12         226.258333   52.9807    69.137500   3.083333
#
#                      precipitation  dew_point  relative_humidity  \
# AddressRegion month
# ...

# %%
agg["temperature"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
agg["wind_speed"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
agg["sealevel_pressure"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
agg["cloud_cover"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
agg["precip_cover"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
agg["precipitation"].plot.hist(bins=50)

# %%
agg["relative_humidity"].plot.hist(bins=50)

# %%
agg["visibility"].plot.hist(bins=100)

# %%
import matplotlib as mpl
import numpy as np
from matplotlib import pyplot
# %matplotlib inline

plt.title("Monthly mean temperature for the year 2020")
plt.xlabel('Month')
plt.ylabel("degrees F +/- from average")
plt.bar(agg["Month"], agg["temperature"], color="steelblue")
plt.show()

# %%
agg.head(25)
# Out:
#                      wind_direction  latitude  cloud_cover   min_temp  \
# AddressRegion month
# Antrim        1          204.412500   54.7156    60.810714   3.542857
#               2          217.939630   54.7156    62.233333   2.622222
#               3          216.225769   54.7156    56.553846   2.619231
#               4          174.027647   54.7156    59.452941   5.588235
#               5          202.729600   54.7156    59.592000   7.348000
#               6          209.015000   54.7156    69.623077  10.480769
#               7          232.190645   54.7156    75.525806  11.145161
#               8          171.741200   54.7156    71.032000  11.692000
#               9          203.485385   54.7156    58.303846   9.373077
#               10         199.895161   54.7156    64.429032   7.019355
#               11         189.962333   54.7156    71.826667   5.983333
#               12         222.945517   54.7156    61.410345   2.631034
# ...

# %%
mergedOne = pd.merge(activities_df, agg, on='AddressRegion', how='inner')

# %%
agg_Roscommon = mergedOne[mergedOne["AddressRegion"]=="Roscommon"]

# %%
# Unique set of activities one can enjoy in the Roscommon County
agg_Roscommon["Name"].unique()
# Out:
# array(['The Restaurant at the Abbey Hotel', 'Wolfhound Adventure Tours',
#        'Thoughts of Ireland Tours', "Jackson's Restaurant", "JJ Harlow's",
#        'Craicncampers', 'Angling Services Ireland', 'Felt Fairies',
#        'Strokestown Golf Club', "Roscommon Farmer's Market",
#        "Benny's Deli, Restaurant and Café", "O'Carolan Heritage Park",
#        "Lough O'Flynn - Wild Goose Bog Loop", "McGourty's Bar",
#        'Carrick-On-Shannon Golf Club', 'Royal Canal Adventures',
#        "Origin Farmer's Market", "J.C.Doorly's - The Corner House",
#        'The Irish Whiskey Trail', 'Sensory Me', 'The Silver Eel',
#        'Roscommon Equestrian Centre', 'The Spa at Kilronan Castle Estate',
#        'Roscommon Leisure Zone', 'Philip Walking', 'Time Pieces',
#        'Shannon River Adventure', 'Les Petites Tartres',
#        "Michelle's Craft Courses", 'Castlerea Railway Museum',
#        'Douglas Hyde Interpretive Centre', 'Rathcroghan Visitor Centre',
# ...

# %%
# List of destinations in Roscommon county
agg_Ros_name = agg_Roscommon[['Name','Tags']]

# %%
#Get the unique values (distinct rows) of the dataframe in python pandas
#drop_duplicates() function is used to get the unique values (rows) of the dataframe in python pandas.
agg_Ros_name.drop_duplicates()
# Out:
#                                                Name                                               Tags
# 0                 The Restaurant at the Abbey Hotel                          Food and Drink,Restaurant
# 12                        Wolfhound Adventure Tours  Cycling,Horse Riding,Equestrian,Kayaking,Activ...
# 24                        Thoughts of Ireland Tours                             Activity Operator,Tour
# 36                             Jackson's Restaurant       Food and Drink,Restaurant,Seafood,Vegetarian
# 48                                      JJ Harlow's             Food and Drink,Restaurant,Pubs and Bar
# 60                                    Craicncampers                               Transport,Coach,Road
# 72                         Angling Services Ireland        Fishing,Angling,Activity Operator,Boat,Tour
# 84                                     Felt Fairies  Craft,Shopping,Learning,Shopping Centres and D...
# ...

# %%
All_Activities = agg_Ros_name.loc[agg_Ros_name['Tags'].str.contains("Food and Drink|Restaurant",case=False)]
All_Activities.drop_duplicates()
# Out:
#                                    Name                                               Tags
# 0     The Restaurant at the Abbey Hotel                          Food and Drink,Restaurant
# 36                 Jackson's Restaurant       Food and Drink,Restaurant,Seafood,Vegetarian
# 48                          JJ Harlow's             Food and Drink,Restaurant,Pubs and Bar
# 108           Roscommon Farmer's Market  Food and Drink,Restaurant,Shopping,Shopping Ce...
# 120   Benny's Deli, Restaurant and Café                     Food and Drink,Restaurant,Cafe
# 156                      McGourty's Bar  Covid Safety Charter,Food and Drink,Restaurant...
# 192              Origin Farmer's Market  Food and Drink,Restaurant,Shopping,Shopping Ce...
# 204     J.C.Doorly's - The Corner House             Food and Drink,Restaurant,Pubs and Bar
# 216             The Irish Whiskey Trail  Food and Drink,Restaurant,Activity Operator,Fo...
# ...

# %%
agg_Ros_name["Tags"][660] # TAgs are getting truncated so I thought of printing this paticular record at index 660
# Out:
# 'Walking,Museums and Attraction,Cafe,Food and Drink,Food Shops,Shopping'

# %%
Golf_Activities = agg_Ros_name.loc[agg_Ros_name['Name'].str.contains("Golf",case=False)]

# %%
Golf_Activities.drop_duplicates()
# Out:
#                              Name  \
# 96          Strokestown Golf Club
# 168  Carrick-On-Shannon Golf Club
# 408   Ballaghaderreen Golf Course
# 420               Boyle Golf Club
# 432           Castlerea Golf Club
# 504           Roscommon Golf Club
# 612             Athlone Golf Club
#
#                                                   Tags
# 96                  Golf Course,Golf,Activity Operator
# 168                                   Golf Course,Golf
# 408                                   Golf Course,Golf
# 420                                   Golf Course,Golf
# 432  Golf Course,Golf,Driving Range,General,Golf Dr...
# 504                 Golf Course,Golf,Activity Operator
# 612                                   Golf Course,Golf

# %%
Walking_Activities = agg_Ros_name.loc[agg_Roscommon["Tags"].str.contains("Walk|Walking",case=False)]
Walking_Activities.drop_duplicates()
# Out:
#                                      Name  \
# 12              Wolfhound Adventure Tours
# 132               O'Carolan Heritage Park
# 144   Lough O'Flynn - Wild Goose Bog Loop
# 180                Royal Canal Adventures
# 288                        Philip Walking
# 396     Strokestown Park House and Garden
# 444                 Cloonfad Scenic Walks
# 564    Lough Key Forest and Activity Park
# 576                  Zipit Lough Key Ltd.
# 660          Shannonbridge Fortifications
# 672                  Kilronan Castle Loop
# 684                   The Suck Valley Way
# 696  The Miner's Way and Historical Trail
# 708           Derryvunny - Old Wood Trail
#
#                                                   Tags
# 12   Cycling,Horse Riding,Equestrian,Kayaking,Activ...
# 132  Walking,Forest Park,Park and Forest Walk,Publi...
# 144           Walking,Forest Park,Park and Forest Walk
# 180  Cycling,Kayaking,Activity Operator,Walking,Boa...
# ...

# %%
# Number of Activities contributing to different genres as specified on the Y-axis with in the Roscommon county!
agg_Ros_name['Tags'].value_counts()[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
#We are looking at the number of activites/places with a commanality and number of activities contributing to entire of the Republic of Ireland
mergedOne['Tags'].value_counts()[:20].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# Result 1: Plot for monthly mean temperature for Roscommon county in 2020! 

import matplotlib as mpl
import numpy as np
from matplotlib import pyplot
# %matplotlib inline

plt.title("Monthly mean temperature plot for Roscommon county in 2020")
plt.xlabel('Month')
plt.ylabel("degrees F +/- from average")
plt.bar(agg_Roscommon["Month"], agg_Roscommon["temperature"], color="steelblue")
plt.show()

# %%
# Result 2: Plot for monthly mean precipitation for Roscommon county in 2020!
plt.title("Monthly mean Precipitation plot for Roscommon county in 2020")
plt.xlabel('Month')
plt.ylabel("millimeters (mm) from average")
plt.bar(agg_Roscommon["Month"], agg_Roscommon["precipitation"], color="teal")
plt.show()

# %%
# Result 3:Plot for monthly mean wind speed for Roscommon county in 2020
plt.title("Monthly mean wind speed plot for Roscommon county in 2020")
plt.xlabel('Month')
plt.ylabel("Kilometers Per hour(Kmph) from average")
plt.bar(agg_Roscommon["Month"], agg_Roscommon["wind_speed"], color="cadetblue")
plt.show()

# %%
# Result 3:Plot for monthly mean relative humidity plot for Roscommon county in 2020!
plt.title("Monthly mean relative humidity plot for Roscommon county in 2020")
plt.xlabel('Month')
plt.ylabel("milligrams (mg/g) +/- from average")
plt.bar(agg_Roscommon["Month"], agg_Roscommon["relative_humidity"], color="cornflowerblue")
plt.show()

# %%
agg_Roscommon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 720 entries, 0 to 719
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               720 non-null    object
#  1   Url                720 non-null    object
#  2   Telephone          684 non-null    object
#  3   Longitude          720 non-null    float64
#  4   Latitude           720 non-null    float64
#  5   AddressRegion      720 non-null    object
#  6   AddressLocality    576 non-null    object
#  7   AddressCountry     720 non-null    object
#  8   Tags               720 non-null    object
#  9   wind_direction     720 non-null    float64
#  10  latitude           720 non-null    float64
#  11  cloud_cover        720 non-null    float64
#  12  min_temp           720 non-null    float64
#  13  precipitation      720 non-null    float64
#  14  dew_point          720 non-null    float64
#  15  relative_humidity  720 non-null    float64
# ...

# %%
mergetest = pd.merge(activities_df,agg, left_index=True, right_index=True,on='AddressRegion', how='inner')

# %%
mergetest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 408 entries, 1 to 12
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               408 non-null    object
#  1   Url                374 non-null    object
#  2   Telephone          374 non-null    object
#  3   Longitude          408 non-null    float64
#  4   Latitude           408 non-null    float64
#  5   AddressRegion      408 non-null    object
#  6   AddressLocality    340 non-null    object
#  7   AddressCountry     408 non-null    object
#  8   Tags               408 non-null    object
#  9   wind_direction     408 non-null    float64
#  10  latitude           408 non-null    float64
#  11  cloud_cover        408 non-null    float64
#  12  min_temp           408 non-null    float64
#  13  precipitation      408 non-null    float64
#  14  dew_point          408 non-null    float64
#  15  relative_humidity  408 non-null    float64
# ...

# %%
mergetest["Tags"].unique()
# Out:
# array(['Covid Safety Charter,Food and Drink,Restaurant,Cafe',
#        'Walking,Activity Operator,Tour',
#        'Climbing,Activity Operator,Kayaking,Day Tour,Tour',
#        'Food and Drink,Restaurant',
#        'Covid Safety Charter,Food and Drink,Restaurant',
#        'Climbing,Activity Operator,Kayaking,Surfing,Walking,Adventure Park',
#        'Walking,Activity Operator',
#        'Shopping,Shopping Centres and Department Store,Food Shops',
#        'Pampering,Health Farm,Spa and Wellness,Specialised Retreat,Fitness and Leisure,Venue,Spa',
#        'Cycling,Activity Operator,Tour',
#        'Cycling,Kayaking,Activity Operator,Walking,Bike Rental,Tour',
#        'Cycling,Walking,Activity Operator,Tour'], dtype=object)

# %%
mergetest['temperature'].min()
# Out:
# -12.4

# %%
mergetest['temperature'].max()
# Out:
# 25.77894736842105

# %%
bins = [15,-10,-5,0,5,10,15,20,25,30 ]
groupNames = ['temp1,temp2,temp3,temp4,temp5']
mergetest["temperature"] = pd.cut(mergetest["temperature",bins,labels=groupNames])

# %%
mergetest["temperature"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
mergetest[mergetest["Name"]=="Antrim"]
# Out:
# Empty DataFrame
# Columns: [Name, Url, Telephone, Longitude, Latitude, AddressRegion, AddressLocality, AddressCountry, Tags, wind_direction, latitude, cloud_cover, min_temp, precipitation, dew_point, relative_humidity, precip_cover, longitude, temperature, max_temp, visibility, wind_speed, snow_depth, sealevel_pressure, snow, wind_gust, wind_chill, year, Month]
# Index: []
#
# [0 rows x 29 columns]

# %%
mergetest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 408 entries, 1 to 12
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               408 non-null    object
#  1   Url                374 non-null    object
#  2   Telephone          374 non-null    object
#  3   Longitude          408 non-null    float64
#  4   Latitude           408 non-null    float64
#  5   AddressRegion      408 non-null    object
#  6   AddressLocality    340 non-null    object
#  7   AddressCountry     408 non-null    object
#  8   Tags               408 non-null    object
#  9   wind_direction     408 non-null    float64
#  10  latitude           408 non-null    float64
#  11  cloud_cover        408 non-null    float64
#  12  min_temp           408 non-null    float64
#  13  precipitation      408 non-null    float64
#  14  dew_point          408 non-null    float64
#  15  relative_humidity  408 non-null    float64
# ...

# %%
type(mergetest["AddressRegion"])
# Out:
# pandas.core.series.Series

# %%
# Saving pandas dataframe into json before sending to MongoDB
import numpy as np
import pandas as pd
  
dataFrame = mergedOne
dataFrame.to_json(r'C:/Users/Rehanawajahat/Desktop/Data Analytics and Programming/Project/mergedOne.json')

# %%
#Importing to MongoDB

# Read json into mongdb
import json
import pymongo
import pandas as pd
from pymongo import MongoClient 
  
# Making Connection
myclient = pymongo.MongoClient('192.168.56.30', 27017)
   
# database 
db = client.Project
   
# Created or Switched to collection names
Collection = db.Finaldata
  
# Loading or Opening the dataframe
with open('C:/Users/Rehanawajahat/Desktop/Data Analytics and Programming/Project/mergedOne.json') as file:
    file_data = json.load(file)
      
# Inserting the loaded data in the Collection if JSON contains data more than one entry insert_many is used else inser_one is used
if isinstance(file_data, list):
    Collection.insert_many(file_data)  
else:
    Collection.insert_one(file_data) 
    
# It Worked! We now h
# Print Output of activities db to confirm Mongodb load
for m in Collection.find({}):
 print(m)

# %%
     
# Using PyMongo
from pymongo import MongoClient
client = MongoClient()
#Making a Connection with MongoClient
cluster = MongoClient("mongodb://localhost:27017/?readPreference=primary&appname=MongoDB%20Compass&ssl=false")
#Getting a Database
db =  cluster["Project"]
#OR db = cluster.test

#Getting a collection (A collection is a group of documents stored int he MongoDB roughly equivalent to a table in a relational database)

collection = db['FinalData']

# %%
# Loading or Opening the dataframe
with open('C:/Users/Rehanawajahat/Desktop/Data Analytics and Programming/Project/mergedOne.json') as file:
    file_data = json.load(file)
      
# Inserting the loaded data in the Collection if JSON contains data more than one entry insert_many is used else inser_one is used
if isinstance(file_data, list):
    Collection.insert_many(file_data)  
else:
    Collection.insert_one(file_data) 
    
# It Worked! We now h
# Print Output of activities db to confirm Mongodb load
for m in Collection.find({}):
 print(m)

# %%
mergedOne.head(12)
# Out:
#                                  Name  \
# 0   The Restaurant at the Abbey Hotel
# 1   The Restaurant at the Abbey Hotel
# 2   The Restaurant at the Abbey Hotel
# 3   The Restaurant at the Abbey Hotel
# 4   The Restaurant at the Abbey Hotel
# 5   The Restaurant at the Abbey Hotel
# 6   The Restaurant at the Abbey Hotel
# 7   The Restaurant at the Abbey Hotel
# 8   The Restaurant at the Abbey Hotel
# 9   The Restaurant at the Abbey Hotel
# 10  The Restaurant at the Abbey Hotel
# 11  The Restaurant at the Abbey Hotel
#
#                                             Url Telephone  Longitude  \
# 0   http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 1   http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 2   http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 3   http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# 4   http://www.abbeyhotel.ie/food-and-wine.html  3.54E+11  -8.193639
# ...

# %%
mergedOne.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62052 entries, 0 to 62051
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               62052 non-null  object
#  1   Url                57828 non-null  object
#  2   Telephone          57468 non-null  object
#  3   Longitude          62052 non-null  float64
#  4   Latitude           62052 non-null  float64
#  5   AddressRegion      62052 non-null  object
#  6   AddressLocality    48240 non-null  object
#  7   AddressCountry     62052 non-null  object
#  8   Tags               61128 non-null  object
#  9   wind_direction     62052 non-null  float64
#  10  latitude           62052 non-null  float64
#  11  cloud_cover        62052 non-null  float64
#  12  min_temp           62052 non-null  float64
#  13  precipitation      62052 non-null  float64
#  14  dew_point          62052 non-null  float64
# ...

# %%
mergedOne["temperature"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
mergedOne["wind_speed"].plot.hist(bins=50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.info()

# %%
df['Tags'].astype(str)

# %%
mergedtwo = pd.merge(activities_df, agg, on='AddressRegion', how='inner')

# %%
mergedtwo

# %%
mergedtwo.info()

# %%
#full outer join

merged3 = pd.merge(activities_df, agg, on='AddressRegion', how='left')

# %%
merged3.info()
